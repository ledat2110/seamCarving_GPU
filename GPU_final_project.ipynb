# %%
import os
working_dir = '/content/drive/MyDrive/GPU_assignments/project'
os.chdir(working_dir)

# %%
# !nvcc seam.cu -o seam
# Out:
# seam.cu(383): warning: variable "bi" was declared but never referenced

# %%
# !./seam 14_15-In.pnm 400
# Out:
# Image size (width * height): 640 x 434
# Vesrion of code: 181
# **********GPU info**********
# Name: Tesla K80
# Compute capability: 3.7
# Num SMs: 13
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 11996954624 bytes
# CMEM: 65536 bytes
# L2 cache: 1572864 bytes
# SMEM / one SM: 114688 bytes
# ****************************
#
# Seam carving by host
# Time: 10480.898 ms
#
# Seam carving by device
# Time: 1425.615 ms
# Error: 0.000000

# %%
1# Đoạn code Python để hiển thị file ảnh pnm ở notebook
# Ví dụ để hiển thị file "img.pnm", ở dòng cuối của code cell
# bạn gõ (không cần dấu ! đằng trước): show_pnm('img.pnm')
# LƯU Ý: bạn phải chạy cell này một lần thì mới gọi được hàm show_pnm
from PIL import Image
import numpy as np
def show_pnm(file_name):
  with open(file_name, 'r') as f:
    vals = f.read().split()
  w = int(vals[1])
  h = int(vals[2])
  print(w, h)
  if vals[0] == 'P2': # Grayscale
    pixels = np.array(vals[4:], dtype=np.uint8).reshape((h, w))
  elif vals[0] == 'P3': # RGB
    pixels = np.array(vals[4:], dtype=np.uint8).reshape((h, w, 3))
  else:
    return None

  return Image.fromarray(pixels)

# Đoạn code Python để hiển thị file chứa ma trận ở notebook
# (một dòng của ma trận ứng với một dòng trong file, 
# các phần tử trên mỗi dòng được cách nhau bởi khoảng trắng) 
# Ví dụ để hiển thị file "pixel_importance.txt", ở dòng cuối của code cell
# bạn gõ: show_matrix('pixel_important.txt')
def show_matrix(matrix_file):
  m = np.loadtxt(matrix_file)
  m = m + m.min()
  m = m / m.max()
  m = m * 255
  m = m.astype(np.uint8)
  return Image.fromarray(m)

# %%
show_pnm("./14_15-In.pnm")
# Out:
# 640 434
# <PIL.Image.Image image mode=RGB size=640x434 at 0x7FC7F556EC50>

# %%
show_pnm("./400_host.pnm")
# Out:
# 400 434
# <PIL.Image.Image image mode=RGB size=400x434 at 0x7FC7F4CD9BA8>

# %%
show_pnm("./400_device.pnm")
# Out:
# 400 434
# <PIL.Image.Image image mode=RGB size=400x434 at 0x7FC7F4D19CC0>

# %%
show_pnm("./in.pnm")
# Out:
# 640 434
# <PIL.Image.Image image mode=RGB size=640x434 at 0x7F72D94A2160>

# %%
show_pnm("./grayScale_host.pnm")
# Out:
# 401 434
# <PIL.Image.Image image mode=L size=401x434 at 0x7F72DB9CB240>

# %%
show_matrix("./pixelsImportance.txt")
# Out:
# <PIL.Image.Image image mode=L size=601x434 at 0x7F72D98DB048>

# %%
show_matrix("./verticalEdge.txt")
# Out:
# <PIL.Image.Image image mode=L size=640x434 at 0x7FAD2F7E6128>
